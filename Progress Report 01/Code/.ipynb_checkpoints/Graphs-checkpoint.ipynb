# %%
using Plots
Plots.plotly();
Plots.default(size=(600,400));
Plots.default(label="");
Plots.default(ticks=:native);

using FFTW

using CSV
using DataFrames
df = CSV.read("experiment.csv", DataFrame);

# %%
fig1 = plot(df."Lines of Data", df."Compress Time (s)");
xlabel!("Lines of data");
ylabel!("Time (s)")
title!("Lines of data versus compression time")
display(fig1);
# Out:
#     <div id="5d1fe506-8fe6-4917-9b81-ca557e344c51" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('5d1fe506-8fe6-4917-9b81-ca557e344c51', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             10.0,
#             1510.0,
#             3010.0,
#             4510.0,
#             6010.0,
#             7510.0,
#             9010.0,
#             10510.0,
#             12010.0,
#             13510.0,
#             15010.0,
#             16510.0,
#             18010.0,
#             19510.0,
#             21010.0,
#             22510.0,
#             24010.0,
#             25510.0,
#             27010.0,
#             28510.0,
#             30010.0,
#             31510.0,
#             33010.0
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             5.698204040527344e-5,
#             0.0014219284057617188,
#             0.0030820369720458984,
#             0.008454084396362305,
#             0.011243820190429688,
#             0.015943050384521484,
#             0.012837886810302734,
#             0.010243654251098633,
#             0.01190495491027832,
#             0.014448165893554688,
#             0.01681685447692871,
#             0.017476797103881836,
#             0.019752979278564453,
#             0.024883031845092773,
#             0.02616596221923828,
#             0.027812957763671875,
#             0.02629399299621582,
#             0.02746891975402832,
#             0.02765512466430664,
#             0.0314488410949707,
#             0.030972957611083984,
#             0.035909175872802734,
#             0.041114091873168945
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "visible": true,
#         "ticks": "inside",
#         "domain": [
#             0.09128390201224845,
#             0.9934383202099738
#         ],
#         "tickcolor": "rgb(0, 0, 0)",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": "Lines of data",
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "mirror": false,
#         "anchor": "y"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "Lines of data versus compression time",
#             "xref": "paper",
#             "x": 0.5423611111111111
#         }
#     ],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "visible": true,
#         "ticks": "inside",
#         "domain": [
#             0.07581474190726165,
#             0.9415463692038496
#         ],
#         "tickcolor": "rgb(0, 0, 0)",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": "Time (s)",
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "mirror": false,
#         "anchor": "x"
#     },
#     "legend_position": {
#         "yanchor": "auto",
#         "xanchor": "auto",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "borderwidth": 1,
#         "tracegroupgap": 0,
#         "y": 1.0,
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": {
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 15
#             },
#             "text": ""
#         },
#         "traceorder": "normal",
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#
#     });
#     </script>

# %%
fig2 = plot(df."Lines of Data", df."Decompress Time (s)");
xlabel!("Lines of data");
ylabel!("Time (s)")
title!("Lines of data versus decompression time")
display(fig2);
# Out:
#     <div id="b1e505bf-8664-4730-8d37-0be462ba7f89" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('b1e505bf-8664-4730-8d37-0be462ba7f89', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             10.0,
#             1510.0,
#             3010.0,
#             4510.0,
#             6010.0,
#             7510.0,
#             9010.0,
#             10510.0,
#             12010.0,
#             13510.0,
#             15010.0,
#             16510.0,
#             18010.0,
#             19510.0,
#             21010.0,
#             22510.0,
#             24010.0,
#             25510.0,
#             27010.0,
#             28510.0,
#             30010.0,
#             31510.0,
#             33010.0
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             5.412101745605469e-5,
#             0.0005030632019042969,
#             0.0009360313415527344,
#             0.001850128173828125,
#             0.00374603271484375,
#             0.004539966583251953,
#             0.005251884460449219,
#             0.0071642398834228516,
#             0.007005214691162109,
#             0.007726192474365234,
#             0.009037017822265625,
#             0.011100292205810547,
#             0.01158905029296875,
#             0.01331782341003418,
#             0.013182878494262695,
#             0.013921022415161133,
#             0.014039993286132812,
#             0.009458780288696289,
#             0.015753984451293945,
#             0.016793251037597656,
#             0.011677980422973633,
#             0.019836902618408203,
#             0.0164029598236084
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "visible": true,
#         "ticks": "inside",
#         "domain": [
#             0.10609871682706327,
#             0.9934383202099737
#         ],
#         "tickcolor": "rgb(0, 0, 0)",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": "Lines of data",
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "mirror": false,
#         "anchor": "y"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "Lines of data versus decompression time",
#             "xref": "paper",
#             "x": 0.5497685185185185
#         }
#     ],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "visible": true,
#         "ticks": "inside",
#         "domain": [
#             0.07581474190726165,
#             0.9415463692038496
#         ],
#         "tickcolor": "rgb(0, 0, 0)",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": "Time (s)",
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "mirror": false,
#         "anchor": "x"
#     },
#     "legend_position": {
#         "yanchor": "auto",
#         "xanchor": "auto",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "borderwidth": 1,
#         "tracegroupgap": 0,
#         "y": 1.0,
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": {
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 15
#             },
#             "text": ""
#         },
#         "traceorder": "normal",
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#
#     });
#     </script>

# %%
fig3 = plot(df."Lines of Data", df."Compression Ratio");
xlabel!("Lines of data");
ylabel!("Compression Ratio")
title!("Lines of data versus compression ratio")
display(fig3);
# Out:
#     <div id="c80b30d0-e4c5-4bae-b01e-0428bf7c3bc9" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('c80b30d0-e4c5-4bae-b01e-0428bf7c3bc9', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             10.0,
#             1510.0,
#             3010.0,
#             4510.0,
#             6010.0,
#             7510.0,
#             9010.0,
#             10510.0,
#             12010.0,
#             13510.0,
#             15010.0,
#             16510.0,
#             18010.0,
#             19510.0,
#             21010.0,
#             22510.0,
#             24010.0,
#             25510.0,
#             27010.0,
#             28510.0,
#             30010.0,
#             31510.0,
#             33010.0
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             2.845771144278607,
#             3.191550934633344,
#             3.096737435381083,
#             3.0404652943466512,
#             3.0256830601092894,
#             3.005294571401022,
#             2.9953894528014793,
#             2.995678120943717,
#             2.9920707701503524,
#             2.999045051117852,
#             3.0462967255570907,
#             3.099430455000719,
#             3.1412491726447955,
#             3.1284601868476893,
#             3.1259385908669945,
#             3.115020274385092,
#             3.106288167028643,
#             3.096330063107896,
#             3.0923275295996997,
#             3.0852246249422026,
#             3.0838064649864525,
#             3.1164672157427704,
#             3.1122694191551328
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "visible": true,
#         "ticks": "inside",
#         "domain": [
#             0.07646908719743364,
#             0.9934383202099737
#         ],
#         "tickcolor": "rgb(0, 0, 0)",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": "Lines of data",
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "mirror": false,
#         "anchor": "y"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "Lines of data versus compression ratio",
#             "xref": "paper",
#             "x": 0.5349537037037038
#         }
#     ],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "visible": true,
#         "ticks": "inside",
#         "domain": [
#             0.07581474190726165,
#             0.9415463692038496
#         ],
#         "tickcolor": "rgb(0, 0, 0)",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": "Compression Ratio",
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "mirror": false,
#         "anchor": "x"
#     },
#     "legend_position": {
#         "yanchor": "auto",
#         "xanchor": "auto",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "borderwidth": 1,
#         "tracegroupgap": 0,
#         "y": 1.0,
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": {
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 15
#             },
#             "text": ""
#         },
#         "traceorder": "normal",
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#
#     });
#     </script>

# %%
fig4 = plot(df."Lines of Data", df."Encrypt Time (s)");
xlabel!("Lines of data");
ylabel!("Encrypt Time (s)")
title!("Lines of data versus encryption time")
display(fig4);
# Out:
#     <div id="2d10c25b-2628-4c51-8c77-b527f823c512" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('2d10c25b-2628-4c51-8c77-b527f823c512', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             10.0,
#             1510.0,
#             3010.0,
#             4510.0,
#             6010.0,
#             7510.0,
#             9010.0,
#             10510.0,
#             12010.0,
#             13510.0,
#             15010.0,
#             16510.0,
#             18010.0,
#             19510.0,
#             21010.0,
#             22510.0,
#             24010.0,
#             25510.0,
#             27010.0,
#             28510.0,
#             30010.0,
#             31510.0,
#             33010.0
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             0.008265018463134766,
#             1.2346031665802002,
#             2.483834981918335,
#             3.7066709995269775,
#             5.106395721435547,
#             6.29496693611145,
#             7.821256875991821,
#             8.91141414642334,
#             9.457523107528687,
#             11.50040602684021,
#             11.94100308418274,
#             13.139831066131592,
#             15.192198991775513,
#             15.257004737854004,
#             17.117594718933105,
#             18.642353057861328,
#             21.60689091682434,
#             21.42377495765686,
#             20.83461093902588,
#             23.77382493019104,
#             24.934611320495605,
#             26.269142150878906,
#             26.270262002944946
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "visible": true,
#         "ticks": "inside",
#         "domain": [
#             0.061654272382618835,
#             0.9934383202099737
#         ],
#         "tickcolor": "rgb(0, 0, 0)",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": "Lines of data",
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "mirror": false,
#         "anchor": "y"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "Lines of data versus encryption time",
#             "xref": "paper",
#             "x": 0.5275462962962963
#         }
#     ],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "visible": true,
#         "ticks": "inside",
#         "domain": [
#             0.07581474190726165,
#             0.9415463692038496
#         ],
#         "tickcolor": "rgb(0, 0, 0)",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": "Encrypt Time (s)",
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "mirror": false,
#         "anchor": "x"
#     },
#     "legend_position": {
#         "yanchor": "auto",
#         "xanchor": "auto",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "borderwidth": 1,
#         "tracegroupgap": 0,
#         "y": 1.0,
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": {
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 15
#             },
#             "text": ""
#         },
#         "traceorder": "normal",
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#
#     });
#     </script>

# %%
fig4 = plot(df."Lines of Data", df."Decrypt Time (s)");
xlabel!("Lines of data");
ylabel!("Decrypt Time (s)")
title!("Lines of data versus decryption time")
display(fig4);
# Out:
#     <div id="b04e38b4-a838-4f43-9da4-fe93aabec053" style="width:600px;height:400px;"></div>
#     <script>
#         requirejs.config({
#         paths: {
#             Plotly: 'https://cdn.plot.ly/plotly-2.6.3.min'
#         }
#     });
#     require(['Plotly'], function (Plotly) {
#
#         Plotly.newPlot('b04e38b4-a838-4f43-9da4-fe93aabec053', [
#     {
#         "xaxis": "x",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y",
#         "x": [
#             10.0,
#             1510.0,
#             3010.0,
#             4510.0,
#             6010.0,
#             7510.0,
#             9010.0,
#             10510.0,
#             12010.0,
#             13510.0,
#             15010.0,
#             16510.0,
#             18010.0,
#             19510.0,
#             21010.0,
#             22510.0,
#             24010.0,
#             25510.0,
#             27010.0,
#             28510.0,
#             30010.0,
#             31510.0,
#             33010.0
#         ],
#         "showlegend": false,
#         "mode": "lines",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "zmax": null,
#         "line": {
#             "color": "rgba(0, 154, 250, 1.000)",
#             "shape": "linear",
#             "dash": "solid",
#             "width": 1
#         },
#         "y": [
#             0.008541345596313477,
#             1.1993489265441895,
#             2.5102078914642334,
#             3.6556930541992188,
#             5.0341410636901855,
#             6.266692876815796,
#             7.764508962631226,
#             8.88274598121643,
#             9.51429033279419,
#             11.365385293960571,
#             12.004706144332886,
#             13.046177864074707,
#             15.078176975250244,
#             15.120185852050781,
#             17.084326028823853,
#             18.54386305809021,
#             23.784772872924805,
#             21.103504180908203,
#             20.83729362487793,
#             23.65444588661194,
#             25.514904260635376,
#             25.221153020858765,
#             25.94036602973938
#         ],
#         "type": "scatter"
#     }
# ]
# , {
#     "showlegend": true,
#     "xaxis": {
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "visible": true,
#         "ticks": "inside",
#         "domain": [
#             0.061654272382618835,
#             0.9934383202099737
#         ],
#         "tickcolor": "rgb(0, 0, 0)",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": "Lines of data",
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "mirror": false,
#         "anchor": "y"
#     },
#     "paper_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "annotations": [
#         {
#             "yanchor": "top",
#             "xanchor": "center",
#             "rotation": -0.0,
#             "y": 1.0,
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 20
#             },
#             "yref": "paper",
#             "showarrow": false,
#             "text": "Lines of data versus decryption time",
#             "xref": "paper",
#             "x": 0.5275462962962963
#         }
#     ],
#     "height": 400,
#     "margin": {
#         "l": 0,
#         "b": 20,
#         "r": 0,
#         "t": 20
#     },
#     "plot_bgcolor": "rgba(255, 255, 255, 1.000)",
#     "yaxis": {
#         "tickangle": 0,
#         "showline": true,
#         "gridcolor": "rgba(0, 0, 0, 0.100)",
#         "showticklabels": true,
#         "gridwidth": 0.5,
#         "titlefont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 15
#         },
#         "visible": true,
#         "ticks": "inside",
#         "domain": [
#             0.07581474190726165,
#             0.9415463692038496
#         ],
#         "tickcolor": "rgb(0, 0, 0)",
#         "linecolor": "rgba(0, 0, 0, 1.000)",
#         "showgrid": true,
#         "zeroline": false,
#         "type": "-",
#         "tickfont": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": "Decrypt Time (s)",
#         "zerolinecolor": "rgba(0, 0, 0, 1.000)",
#         "mirror": false,
#         "anchor": "x"
#     },
#     "legend_position": {
#         "yanchor": "auto",
#         "xanchor": "auto",
#         "bordercolor": "rgba(0, 0, 0, 1.000)",
#         "bgcolor": "rgba(255, 255, 255, 1.000)",
#         "borderwidth": 1,
#         "tracegroupgap": 0,
#         "y": 1.0,
#         "font": {
#             "color": "rgba(0, 0, 0, 1.000)",
#             "family": "sans-serif",
#             "size": 11
#         },
#         "title": {
#             "font": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "family": "sans-serif",
#                 "size": 15
#             },
#             "text": ""
#         },
#         "traceorder": "normal",
#         "x": 1.0
#     },
#     "width": 600
# }
# );
#
#     });
#     </script>
